# %% [markdown]
# Y=Xb+c
# minimos cuadrados miniizar los errores al cuadrado
# e=y-xb
# minn/sume^2=e'.e
# minn/sume^2=(y-xb)'.(y-xb)
# minn/sume^2=(y.y'-b'x'y+y'xb+....)
# de'.e/db

# %% [markdown]
# ![image.png](attachment:8bdaf5df-6241-440a-aa31-b7ec7059c9b1.png)

# %% [markdown]
# multicolinealidad perfecta
