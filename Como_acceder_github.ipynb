# %% [markdown]
# <h3> Como extraer las carpetas que tengo en git <h3>

# %% [markdown]
# <p>
# &nbsp;&nbsp;&nbsp;&nbsp;1. Instalar github, si es la pc tiene windows con el instalador de la misma pagina de git hub https://git-scm.com/downloads)
# </p>
# <p>
# &nbsp;&nbsp;&nbsp;&nbsp;[Descargar GitHub](https://git-scm.com/downloads)
# </p>
# &nbsp;&nbsp;&nbsp;&nbsp;2. Instalar github, si es la pc tiene windows con el instalador de la misma pagina de git hub https://git-scm.com/downloads)
# <p>
# &nbsp;&nbsp;&nbsp;&nbsp;3. En la consola ponemos el siguiente codigo "py -m pip install jupyterlab-git", el cual instala jupiterlab con la extensión de git
# </p>
# <p>
# &nbsp;&nbsp;&nbsp;&nbsp;4. En la terminal C:\Users\user>cd "cd Desktop" para irnos a escritorio.
# </p>
# <p>
# &nbsp;&nbsp;&nbsp;&nbsp;5. Luego  C:\Users\user\Desktop>"git clone https://github.com/juaca2922/Econmetria-JupiterLab-.git" el cual sirve para clonar (descargar) el repositorio de GitHub a nuestra PC.
# </p>
# <p>
# &nbsp;&nbsp;&nbsp;&nbsp;6. Seguidamente ponemos  C:\Users\user\Desktop>"cd Econmetria-JupiterLab-"para entrar a la carpeta de GitHub.
# </p>
# <p>
# &nbsp;&nbsp;&nbsp;&nbsp;7. Finalmente ponemos  C:\Users\user\Desktop>"py -m jupyterlab" para abrir jupiter lab con la extensión de jupiter lab tendriamos que observar la extensionde git, asi como la siguiente imagen.
#
# ![bb652c96-e845-455c-8169-e077b6c704ec.jpg](attachment:9b309ef3-6ae2-4039-8453-1f91181b16cd.jpg)
# </p>
# <p>
# &nbsp;&nbsp;&nbsp;&nbsp;8. En el tab de git seleccionamos "Track this file(+)" para cada archivo nuevo de py, txt, etc para que lo guardemos en git, es decir hacem un "comit" es decir onfirmar los cambios realizados en una base de datos y hacerlos permanentes.
#
# ![Captura de pantalla (578).png](attachment:3942f797-077a-4258-af9b-a9b030359b8c.png)
# </p>
# <p>
# &nbsp;&nbsp;&nbsp;&nbsp;9. Seguidamente ponemos  C:\Users\user\Desktop>"cd Econmetria-JupiterLab-"para entrar a la carpeta de GitHub.
# </p>
